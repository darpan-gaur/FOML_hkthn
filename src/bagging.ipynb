# %%
import numpy as np
import random

import pandas as pd
from scipy import stats

# decision tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %%
# set seed, 42
seed = 23
random.seed(seed)
np.random.seed(seed)

# %%
# load data
train_data = pd.read_csv('../data/preprocessed_train.csv')
test_data = pd.read_csv('../data/preprocessed_test.csv')

# train_data = pd.read_csv('../data/preprocessed_train_CorrDrop.csv')
# test_data = pd.read_csv('../data/preprocessed_test_CorrDrop.csv')

# %%
# Set the 'UID' column as the index
train_data.set_index('UID', inplace=True)

# Set the 'UID' column as the index
test_data.set_index('UID', inplace=True)

# %%
# Define the mapping for 'Target' column
target_mapping = {'low': 0, 'medium': 1, 'high': 2}

# Apply the mapping to the 'Target' column
train_labels = train_data['Target'].map(target_mapping)

# Drop the 'Target' column from the training data
train_data = train_data.drop('Target', axis=1)

# %%
# make train data with 22514 data of each class

# Separate the data based on the target classes
low_class = train_data[train_labels == 0]
medium_class = train_data[train_labels == 1]
high_class = train_data[train_labels == 2]

# Get the number of samples in each class
low_class_count = len(low_class)
medium_class_count = len(medium_class)
high_class_count = len(high_class)

# Set the number of samples to be selected from each class
num_samples = min(low_class_count, medium_class_count, high_class_count)
num_samples_m = int(num_samples*1.0)

# Randomly sample data from each class
low_class_sample = low_class.sample(n=num_samples, random_state=seed)
medium_class_sample = medium_class.sample(n=num_samples_m, random_state=seed)
high_class_sample = high_class.sample(n=num_samples, random_state=seed)

# Concatenate the sampled data
train_data_sampled = pd.concat([low_class_sample, medium_class_sample, high_class_sample])

# Separate the features and target variable
X_sampled = train_data_sampled
y_sampled = train_labels.loc[train_data_sampled.index]

# Display the count of unique values in the target variable
print(y_sampled.value_counts())
# Out:
# Target
# 0    22514
# 1    22514
# 2    22514
# Name: count, dtype: int64

# %%
# Split the data into training and validation sets
X_train, X_valid, y_train, y_valid = train_test_split(train_data, train_labels, test_size=0.1, random_state=seed)
# X_train, X_valid, y_train, y_valid = train_test_split(X_sampled, y_sampled, test_size=0.1, random_state=seed)
# X_train, y_train = X_sampled, y_sampled
# X_valid, y_valid = X_sampled, y_sampled

# Display the shapes of the training and validation sets
print(f"X_train shape: {X_train.shape}")
print(f"X_valid shape: {X_valid.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_valid shape: {y_valid.shape}")
# Out:
# X_train shape: (101312, 20)
# X_valid shape: (11257, 20)
# y_train shape: (101312,)
# y_valid shape: (11257,)

# %% [markdown]
# ## bagging

# %%
# decision tree
# clf = DecisionTreeClassifier(random_state=seed)
clf = LGBMClassifier(
    random_state=seed,
    n_jobs=1
)
# clf = RandomForestClassifier(
#     n_estimators=200, 
#     max_depth=10,
#     random_state=seed,
# )


# bagging_clf = BaggingClassifier(estimator=clf, n_estimators=100, random_state=seed, n_jobs=-1, bootstrap_features=True, oob_score=True)
bagging_clf = BaggingClassifier(estimator=clf, n_estimators=100, random_state=seed, n_jobs=-1, bootstrap_features=True)

# fit the model
bagging_clf.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014140 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1587
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.612225
# [LightGBM] [Info] Start training from score -0.510549
# [LightGBM] [Info] Start training from score -1.607485
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.020369 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3377
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.617137
# [LightGBM] [Info] Start training from score -0.508397
# [LightGBM] [Info] Start training from score -1.609063
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.046583 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2967
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.607485
# [LightGBM] [Info] Start training from score -0.507659[LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015236 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
#
# [LightGBM] [Info] Start training from score -1.620974[LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019869 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.[LightGBM] [Info] Total Bins 2370
#
#
# [LightGBM] [Info] Total Bins 1747[LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
#
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.606255[LightGBM] [Info] Start training from score -1.605124
#
# [LightGBM] [Info] Start training from score -0.508528
# [LightGBM] [Info] Start training from score -1.620724[LightGBM] [Info] Start training from score -0.511388
#
# [LightGBM] [Info] Start training from score -1.610939
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.045943 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3291
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.608767
# [LightGBM] [Info] Start training from score -0.511998
# [LightGBM] [Info] Start training from score -1.606599
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013579 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3133
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.609507
# [LightGBM] [Info] Start training from score -0.509119
# [LightGBM] [Info] Start training from score -1.614504
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014763 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2929
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.606255
# [LightGBM] [Info] Start training from score -0.510845
# [LightGBM] [Info] Start training from score -1.612572
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012628 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2958
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.608866
# [LightGBM] [Info] Start training from score -0.509645
# [LightGBM] [Info] Start training from score -1.613562
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013890 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.[LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015460 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
#
# [LightGBM] [Info] Total Bins 2674
# [LightGBM] [Info] Total Bins 2463
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.608816
# [LightGBM] [Info] Start training from score -1.605370
# [LightGBM] [Info] Start training from score -0.506528
# [LightGBM] [Info] Start training from score -0.509612
# [LightGBM] [Info] Start training from score -1.623073
# [LightGBM] [Info] Start training from score -1.617187
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019317 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3058
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.603749
# [LightGBM] [Info] Start training from score -0.513629[LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012716 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
#
# [LightGBM] [Info] Total Bins 2131[LightGBM] [Info] Start training from score -1.606747
#
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.602964
# [LightGBM] [Info] Start training from score -0.512376
# [LightGBM] [Info] Start training from score -1.611285
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015156 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2758
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018927 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2744
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.608816
# [LightGBM] [Info] Start training from score -0.510418
# [LightGBM] [Info] Start training from score -1.611285
# [LightGBM] [Info] Start training from score -1.609211
# [LightGBM] [Info] Start training from score -0.509333
# [LightGBM] [Info] Start training from score -1.614157
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018559 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2706
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.603994
# [LightGBM] [Info] Start training from score -0.507331
# [LightGBM] [Info] Start training from score -1.625527
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.046278 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3697
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.602229
# [LightGBM] [Info] Start training from score -0.510582
# [LightGBM] [Info] Start training from score -1.617435
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047596 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3319
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018922 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2443
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.612572
# [LightGBM] [Info] Start training from score -1.609655[LightGBM] [Info] Start training from score -0.509744
#
# [LightGBM] [Info] Start training from score -1.609556
# [LightGBM] [Info] Start training from score -0.510730
# [LightGBM] [Info] Start training from score -1.609507
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014604 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2263
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.605812
# [LightGBM] [Info] Start training from score -0.514669
# [LightGBM] [Info] Start training from score -1.601592
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015284 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2713
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.608027
# [LightGBM] [Info] Start training from score -0.512162
# [LightGBM] [Info] Start training from score -1.606845
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.049407 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4149
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014353 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3226
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.606648
# [LightGBM] [Info] Start training from score -0.505840
# [LightGBM] [Info] Start training from score -1.627385[LightGBM] [Info] Start training from score -1.607978
#
# [LightGBM] [Info] Start training from score -0.512788
# [LightGBM] [Info] Start training from score -1.605026
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013820 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3656
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.616491
# [LightGBM] [Info] Start training from score -0.513448
# [LightGBM] [Info] Start training from score -1.594663
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015048 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2410
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014150 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3202
# [LightGBM] [Info] Start training from score -1.609310[LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
#
# [LightGBM] [Info] Start training from score -0.511290
# [LightGBM] [Info] Start training from score -1.608175
# [LightGBM] [Info] Start training from score -1.597926
# [LightGBM] [Info] Start training from score -0.513234
# [LightGBM] [Info] Start training from score -1.613810
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015407 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2561
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.614108
# [LightGBM] [Info] Start training from score -0.508249
# [LightGBM] [Info] Start training from score -1.612522
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015094 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2446
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.598903
# [LightGBM] [Info] Start training from score -0.512970
# [LightGBM] [Info] Start training from score -1.613612
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.046192 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3579
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.603798
# [LightGBM] [Info] Start training from score -0.510615
# [LightGBM] [Info] Start training from score -1.615745
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014370 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2918
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.606648
# [LightGBM] [Info] Start training from score -0.510714
# [LightGBM] [Info] Start training from score -1.612572
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014450 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3185
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.612225
# [LightGBM] [Info] Start training from score -0.509284
# [LightGBM] [Info] Start training from score -1.611285
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019186 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3663
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.596707
# [LightGBM] [Info] Start training from score -0.512953
# [LightGBM] [Info] Start training from score -1.615894
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014716 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2285
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.597731
# [LightGBM] [Info] Start training from score -0.514438
# [LightGBM] [Info] Start training from score -1.610396
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014268 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2191
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.603651
# [LightGBM] [Info] Start training from score -0.511932
# [LightGBM] [Info] Start training from score -1.611928
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014197 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2952
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.601103
# [LightGBM] [Info] Start training from score -0.511635
# [LightGBM] [Info] Start training from score -1.615398
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013396 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2367
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.609408
# [LightGBM] [Info] Start training from score -0.513135
# [LightGBM] [Info] Start training from score -1.602572
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014984 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2043
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.609754
# [LightGBM] [Info] Start training from score -0.509662
# [LightGBM] [Info] Start training from score -1.612621
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.020673 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1839
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.606845
# [LightGBM] [Info] Start training from score -0.512327
# [LightGBM] [Info] Start training from score -1.607535
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013681 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3178
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.617187
# [LightGBM] [Info] Start training from score -0.509925
# [LightGBM] [Info] Start training from score -1.604436
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.021230 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3192
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.595393
# [LightGBM] [Info] Start training from score -0.514785
# [LightGBM] [Info] Start training from score -1.611730
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013733 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3220
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.606845
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012400 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2914
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -0.510549
# [LightGBM] [Info] Start training from score -1.612869
# [LightGBM] [Info] Start training from score -1.603896
# [LightGBM] [Info] Start training from score -0.513811
# [LightGBM] [Info] Start training from score -1.606058
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015895 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1640
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.615596
# [LightGBM] [Info] Start training from score -0.508463
# [LightGBM] [Info] Start training from score -1.610396
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018042 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3042
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.602229
# [LightGBM] [Info] Start training from score -0.511866
# [LightGBM] [Info] Start training from score -1.613562
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.046547 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3300
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.610544
# [LightGBM] [Info] Start training from score -0.511701
# [LightGBM] [Info] Start training from score -1.605714
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013483 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2713
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.606796
# [LightGBM] [Info] Start training from score -0.511882
# [LightGBM] [Info] Start training from score -1.608915
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013457 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3389
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.615398
# [LightGBM] [Info] Start training from score -0.505840
# [LightGBM] [Info] Start training from score -1.618530
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018677 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3044
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.608964
# [LightGBM] [Info] Start training from score -0.510368
# [LightGBM] [Info] Start training from score -1.611285
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013867 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2572
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013417 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Start training from score -1.605763[LightGBM] [Info] Total Bins 4037
#
# [LightGBM] [Info] Start training from score -0.511355
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20[LightGBM] [Info] Start training from score -1.611533
#
# [LightGBM] [Info] Start training from score -1.615398
# [LightGBM] [Info] Start training from score -0.508102
# [LightGBM] [Info] Start training from score -1.611681
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014157 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2904
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.610198
# [LightGBM] [Info] Start training from score -0.508775
# [LightGBM] [Info] Start training from score -1.614852
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018452 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3054
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.615745
# [LightGBM] [Info] Start training from score -0.507774
# [LightGBM] [Info] Start training from score -1.612324
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.054106 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2301
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.613265
# [LightGBM] [Info] Start training from score -0.510566
# [LightGBM] [Info] Start training from score -1.606402
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.049285 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3286
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.616988
# [LightGBM] [Info] Start training from score -0.508676
# [LightGBM] [Info] Start training from score -1.608372
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014130 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3266
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.605419
# [LightGBM] [Info] Start training from score -0.510928
# [LightGBM] [Info] Start training from score -1.613166
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.050383 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2940
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.604485
# [LightGBM] [Info] Start training from score -0.507151
# [LightGBM] [Info] Start training from score -1.625577
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.020458 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3146
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.612473
# [LightGBM] [Info] Start training from score -0.510089
# [LightGBM] [Info] Start training from score -1.608619
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.048835 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2942
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.602376
# [LightGBM] [Info] Start training from score -0.511323
# [LightGBM] [Info] Start training from score -1.615050
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014520 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2395
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.608866
# [LightGBM] [Info] Start training from score -0.511059
# [LightGBM] [Info] Start training from score -1.609310
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016084 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2234
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.607239
# [LightGBM] [Info] Start training from score -0.515793
# [LightGBM] [Info] Start training from score -1.596854
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019005 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3561
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.614455
# [LightGBM] [Info] Start training from score -0.512031
# [LightGBM] [Info] Start training from score -1.600858
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019032 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3036
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.613860
# [LightGBM] [Info] Start training from score -0.508118
# [LightGBM] [Info] Start training from score -1.613166
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015314 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3087
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.609260
# [LightGBM] [Info] Start training from score -0.509809
# [LightGBM] [Info] Start training from score -1.612671
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.020362 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2223
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.607584
# [LightGBM] [Info] Start training from score -0.514735
# [LightGBM] [Info] Start training from score -1.599635
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.045182 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3296
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.605173
# [LightGBM] [Info] Start training from score -0.511306
# [LightGBM] [Info] Start training from score -1.612275
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.045007 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3333
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.615646
# [LightGBM] [Info] Start training from score -0.511306
# [LightGBM] [Info] Start training from score -1.601837
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018766 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3216
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.610297
# [LightGBM] [Info] Start training from score -0.512788
# [LightGBM] [Info] Start training from score -1.602719
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014742 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2503
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.605370
# [LightGBM] [Info] Start training from score -0.512393
# [LightGBM] [Info] Start training from score -1.608816
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.044729 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3784
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.598268
# [LightGBM] [Info] Start training from score -0.512805
# [LightGBM] [Info] Start training from score -1.614752
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015144 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1835
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.613711
# [LightGBM] [Info] Start training from score -0.507315
# [LightGBM] [Info] Start training from score -1.615745
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019491 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2191
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.613860
# [LightGBM] [Info] Start training from score -0.508266
# [LightGBM] [Info] Start training from score -1.612720
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.048353 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3379
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.597780
# [LightGBM] [Info] Start training from score -0.513250
# [LightGBM] [Info] Start training from score -1.613909
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015612 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2213
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.612176
# [LightGBM] [Info] Start training from score -0.505562
# [LightGBM] [Info] Start training from score -1.622623
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013943 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4005
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.597049
# [LightGBM] [Info] Start training from score -0.514372
# [LightGBM] [Info] Start training from score -1.611285
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012908 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3816
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.617883
# [LightGBM] [Info] Start training from score -0.509185
# [LightGBM] [Info] Start training from score -1.605960
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013996 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2195
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.608077
# [LightGBM] [Info] Start training from score -0.510451
# [LightGBM] [Info] Start training from score -1.611928
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015279 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2898
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.607239
# [LightGBM] [Info] Start training from score -0.508463
# [LightGBM] [Info] Start training from score -1.618779
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013916 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3209
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.611730
# [LightGBM] [Info] Start training from score -0.508693
# [LightGBM] [Info] Start training from score -1.613562
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.048495 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3006
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.605714
# [LightGBM] [Info] Start training from score -0.510615
# [LightGBM] [Info] Start training from score -1.613810
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.046923 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3210
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.614554
# [LightGBM] [Info] Start training from score -0.507774
# [LightGBM] [Info] Start training from score -1.613513
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014376 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3025
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.608077
# [LightGBM] [Info] Start training from score -0.509514
# [LightGBM] [Info] Start training from score -1.614752
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.028576 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1990
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.601935
# [LightGBM] [Info] Start training from score -0.514901
# [LightGBM] [Info] Start training from score -1.604780
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013928 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2606
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.607485
# [LightGBM] [Info] Start training from score -0.514669
# [LightGBM] [Info] Start training from score -1.599929
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013814 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2681
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.605911
# [LightGBM] [Info] Start training from score -0.510681
# [LightGBM] [Info] Start training from score -1.613414
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.020681 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2558
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013788 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3088
# [LightGBM] [Info] Start training from score -1.608915
# [LightGBM] [Info] Start training from score -0.510796[LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
#
# [LightGBM] [Info] Start training from score -1.610050
# [LightGBM] [Info] Start training from score -1.616143
# [LightGBM] [Info] Start training from score -0.509005
# [LightGBM] [Info] Start training from score -1.608225
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014064 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3052
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.603062
# [LightGBM] [Info] Start training from score -0.513168
# [LightGBM] [Info] Start training from score -1.608816
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019613 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2192
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.608570
# [LightGBM] [Info] Start training from score -0.507938
# [LightGBM] [Info] Start training from score -1.619029
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015823 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2463
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.607535
# [LightGBM] [Info] Start training from score -0.510500
# [LightGBM] [Info] Start training from score -1.612324
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014922 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2803
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.610445
# [LightGBM] [Info] Start training from score -0.510928
# [LightGBM] [Info] Start training from score -1.608126
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013885 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3221
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.610396
# [LightGBM] [Info] Start training from score -0.511257
# [LightGBM] [Info] Start training from score -1.607190
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014173 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2367
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.612918
# [LightGBM] [Info] Start training from score -0.511438
# [LightGBM] [Info] Start training from score -1.604142
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.045832 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3506
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.604584
# [LightGBM] [Info] Start training from score -0.512162
# [LightGBM] [Info] Start training from score -1.610297
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019713 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2207
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.601592
# [LightGBM] [Info] Start training from score -0.511866
# [LightGBM] [Info] Start training from score -1.614207
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012670 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2029
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.602033
# [LightGBM] [Info] Start training from score -0.510500
# [LightGBM] [Info] Start training from score -1.617883
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013305 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3296
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.614554
# [LightGBM] [Info] Start training from score -0.508873
# [LightGBM] [Info] Start training from score -1.610198
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009414 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2240
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.609162
# [LightGBM] [Info] Start training from score -0.508135
# [LightGBM] [Info] Start training from score -1.617833
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009869 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2701
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.606550
# [LightGBM] [Info] Start training from score -0.510319
# [LightGBM] [Info] Start training from score -1.613860
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008319 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2461
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.613315
# [LightGBM] [Info] Start training from score -0.509925
# [LightGBM] [Info] Start training from score -1.608274
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009598 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2373
# [LightGBM] [Info] Number of data points in the train set: 101312, number of used features: 20
# [LightGBM] [Info] Start training from score -1.603307
# [LightGBM] [Info] Start training from score -0.511767
# [LightGBM] [Info] Start training from score -1.612770
# BaggingClassifier(bootstrap_features=True,
#                   estimator=LGBMClassifier(n_jobs=1, random_state=23),
#                   n_estimators=100, n_jobs=-1, random_state=23)

# %%
# cross validation
n_splits=10
cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)

f1 = []
acc = []

for (train, test), i in zip(cv.split(X_train, y_train), range(n_splits)):
    bagging_clf.fit(X_train.iloc[train], y_train.iloc[train])
    
    train_preds = bagging_clf.predict(X_train.iloc[train])
    valid_preds = bagging_clf.predict(X_train.iloc[test])

    train_accuracy = accuracy_score(y_train.iloc[train], train_preds)
    train_f1 = f1_score(y_train.iloc[train], train_preds, average='macro')

    valid_accuracy = accuracy_score(y_train.iloc[test], valid_preds)
    valid_f1 = f1_score(y_train.iloc[test], valid_preds, average='macro')

    f1.append(valid_f1)
    acc.append(valid_accuracy)

    print(f"Fold {i+1}/{n_splits}")
    print(f"Train Accuracy: {train_accuracy:.4f}, Train F1: {train_f1:.4f}")
    print(f"Validation Accuracy: {valid_accuracy:.4f}, Validation F1: {valid_f1:.4f}")
    print("")
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012432 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2370
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.610261
# [LightGBM] [Info] Start training from score -0.505121
# [LightGBM] [Info] Start training from score -1.625914
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017993 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1747
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.609822
# [LightGBM] [Info] Start training from score -0.511063
# [LightGBM] [Info] Start training from score -1.608342
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012920 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2263
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.610645
# [LightGBM] [Info] Start training from score -0.510387
# [LightGBM] [Info] Start training from score -1.609548
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013826 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1587
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.619524
# [LightGBM] [Info] Start training from score -0.506521
# [LightGBM] [Info] Start training from score -1.612348
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013465 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2131
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013051 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Start training from score -1.609932
# [LightGBM] [Info] Start training from score -0.510533
# [LightGBM] [Info] Total Bins 2713
# [LightGBM] [Info] Start training from score -1.609822
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.609932
# [LightGBM] [Info] Start training from score -0.508306
# [LightGBM] [Info] Start training from score -1.616537
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.043584 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4149
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.606590
# [LightGBM] [Info] Start training from score -0.510424
# [LightGBM] [Info] Start training from score -1.613504
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.041308 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3202
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.608451
# [LightGBM] [Info] Start training from score -0.511520
# [LightGBM] [Info] Start training from score -1.608342
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017729 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3058
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.620688
# [LightGBM] [Info] Start training from score -0.507504
# [LightGBM] [Info] Start training from score -1.608232
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.043540 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3377
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.608561
# [LightGBM] [Info] Start training from score -0.511740
# [LightGBM] [Info] Start training from score -1.607575
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012360 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2674
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.592042
# [LightGBM] [Info] Start training from score -0.513865
# [LightGBM] [Info] Start training from score -1.617919
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017529 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2967
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011942 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Total Bins 2758
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.614165
# [LightGBM] [Info] Start training from score -0.508762
# [LightGBM] [Info] Start training from score -1.610920[LightGBM] [Info] Start training from score -1.614826
# [LightGBM] [Info] Start training from score -0.509218
#
# [LightGBM] [Info] Start training from score -1.608890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013982 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2929
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.604351
# [LightGBM] [Info] Start training from score -0.514873
# [LightGBM] [Info] Start training from score -1.602443
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016696 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2744
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.601029
# [LightGBM] [Info] Start training from score -0.509383
# [LightGBM] [Info] Start training from score -1.622297
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013398 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2446
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.605716
# [LightGBM] [Info] Start training from score -0.509638
# [LightGBM] [Info] Start training from score -1.616758
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013692 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2463
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012541 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2410
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.609493
# [LightGBM] [Info] Start training from score -0.510241
# [LightGBM] [Info] Start training from score -1.611139
# [LightGBM] [Info] Start training from score -1.603860
# [LightGBM] [Info] Start training from score -0.513461
# [LightGBM] [Info] Start training from score -1.607137
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013895 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3291
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013307 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3656
# [LightGBM] [Info] Start training from score -1.608725
# [LightGBM] [Info] Start training from score -0.509456
# [LightGBM] [Info] Start training from score -1.614275
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012077 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3697
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.601899
# [LightGBM] [Info] Start training from score -0.514323
# [LightGBM] [Info] Start training from score -1.606536
# [LightGBM] [Info] Start training from score -1.600702
# [LightGBM] [Info] Start training from score -0.513590
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.042673 seconds.
# You can set `force_col_wise=true` to remove the overhead.[LightGBM] [Info] Start training from score -1.609932
#
# [LightGBM] [Info] Total Bins 3133
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013133 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2561
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013258 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2958
# [LightGBM] [Info] Start training from score -1.620299[LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
#
# [LightGBM] [Info] Start training from score -0.507486
# [LightGBM] [Info] Start training from score -1.608670
# [LightGBM] [Info] Start training from score -1.609383
# [LightGBM] [Info] Start training from score -0.511649
# [LightGBM] [Info] Start training from score -1.607028
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.044301 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3319
# [LightGBM] [Info] Start training from score -1.601029
# [LightGBM] [Info] Start training from score -0.509876
# [LightGBM] [Info] Start training from score -1.620799
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016480 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20[LightGBM] [Info] Total Bins 2443
#
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.610865
# [LightGBM] [Info] Start training from score -0.508434
# [LightGBM] [Info] Start training from score -1.615212
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013462 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.[LightGBM] [Info] Start training from score -1.598910
#
# [LightGBM] [Info] Start training from score -0.513076
# [LightGBM] [Info] Start training from score -1.613284[LightGBM] [Info] Total Bins 2918
#
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.605661
# [LightGBM] [Info] Start training from score -0.510022
# [LightGBM] [Info] Start training from score -1.615654
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.046041 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3579
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.609877
# [LightGBM] [Info] Start training from score -0.511886
# [LightGBM] [Info] Start training from score -1.605825
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.043038 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3226
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.618582
# [LightGBM] [Info] Start training from score -0.505230
# [LightGBM] [Info] Start training from score -1.617200
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018071 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3663
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.599670
# [LightGBM] [Info] Start training from score -0.516858
# [LightGBM] [Info] Start training from score -1.601246
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016411 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2706
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.608397
# [LightGBM] [Info] Start training from score -0.513810
# [LightGBM] [Info] Start training from score -1.601572
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013389 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3185
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.609109
# [LightGBM] [Info] Start training from score -0.507796
# [LightGBM] [Info] Start training from score -1.618915
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012223 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2367
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.610810
# [LightGBM] [Info] Start training from score -0.512747
# [LightGBM] [Info] Start training from score -1.602334
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013623 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2285
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.611909
# [LightGBM] [Info] Start training from score -0.507413
# [LightGBM] [Info] Start training from score -1.617255
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014031 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2952
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.610096
# [LightGBM] [Info] Start training from score -0.510807
# [LightGBM] [Info] Start training from score -1.608835
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013520 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2043
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.606098
# [LightGBM] [Info] Start training from score -0.512893
# [LightGBM] [Info] Start training from score -1.606590
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.042012 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3300
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.622797
# [LightGBM] [Info] Start training from score -0.508416
# [LightGBM] [Info] Start training from score -1.603424
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013953 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3087
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014135 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2572
# [LightGBM] [Info] Start training from score -1.607302
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -0.508197
# [LightGBM] [Info] Start training from score -1.619524
# [LightGBM] [Info] Start training from score -1.602661
# [LightGBM] [Info] Start training from score -0.513443
# [LightGBM] [Info] Start training from score -1.608397
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012739 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2191
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.601355
# [LightGBM] [Info] Start training from score -0.510387
# [LightGBM] [Info] Start training from score -1.618915
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.041557 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4037
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.609877
# [LightGBM] [Info] Start training from score -0.513956
# [LightGBM] [Info] Start training from score -1.599670
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015387 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3042
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.617974
# [LightGBM] [Info] Start training from score -0.506485
# [LightGBM] [Info] Start training from score -1.614000
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016647 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3044
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.615599
# [LightGBM] [Info] Start training from score -0.506812
# [LightGBM] [Info] Start training from score -1.615378
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017494 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3192
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.602280
# [LightGBM] [Info] Start training from score -0.512912
# [LightGBM] [Info] Start training from score -1.610371
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013316 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1640
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.613834
# [LightGBM] [Info] Start training from score -0.510716
# [LightGBM] [Info] Start training from score -1.605388
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016867 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3146
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.618970
# [LightGBM] [Info] Start training from score -0.509821
# [LightGBM] [Info] Start training from score -1.602988
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011725 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2914
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.613449
# [LightGBM] [Info] Start training from score -0.507031
# [LightGBM] [Info] Start training from score -1.616868
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017755 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3054
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.607904
# [LightGBM] [Info] Start training from score -0.512857
# [LightGBM] [Info] Start training from score -1.604897
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013656 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3389
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.597609
# [LightGBM] [Info] Start training from score -0.508726
# [LightGBM] [Info] Start training from score -1.627811
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013259 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2301
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.606153
# [LightGBM] [Info] Start training from score -0.513040
# [LightGBM] [Info] Start training from score -1.606098
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016683 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2223
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011718 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.[LightGBM] [Info] Start training from score -1.614606
#
# [LightGBM] [Info] Start training from score -0.507650
# [LightGBM] [Info] Total Bins 2942
# [LightGBM] [Info] Start training from score -1.613834[LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
#
# [LightGBM] [Info] Start training from score -1.614110
# [LightGBM] [Info] Start training from score -0.507413
# [LightGBM] [Info] Start training from score -1.615047
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.054510 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3220
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.622519
# [LightGBM] [Info] Start training from score -0.505030
# [LightGBM] [Info] Start training from score -1.613890
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012875 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3286
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.613119
# [LightGBM] [Info] Start training from score -0.504303
# [LightGBM] [Info] Start training from score -1.625524
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012812 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2234
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.613834
# [LightGBM] [Info] Start training from score -0.512435
# [LightGBM] [Info] Start training from score -1.600268
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.051217 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3266
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.611194
# [LightGBM] [Info] Start training from score -0.510131
# [LightGBM] [Info] Start training from score -1.609767
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.044720 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3561
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.619801
# [LightGBM] [Info] Start training from score -0.504812
# [LightGBM] [Info] Start training from score -1.617255
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018342 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2940
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.606700
# [LightGBM] [Info] Start training from score -0.510150
# [LightGBM] [Info] Start training from score -1.614220
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017771 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3036
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.607794
# [LightGBM] [Info] Start training from score -0.508069
# [LightGBM] [Info] Start training from score -1.619413
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011979 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2395
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.603370
# [LightGBM] [Info] Start training from score -0.513461
# [LightGBM] [Info] Start training from score -1.607630
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018264 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1839
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.608561
# [LightGBM] [Info] Start training from score -0.510497
# [LightGBM] [Info] Start training from score -1.611304
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012367 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2904
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.621076
# [LightGBM] [Info] Start training from score -0.508215
# [LightGBM] [Info] Start training from score -1.605716
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012557 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3178
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.617753
# [LightGBM] [Info] Start training from score -0.507158
# [LightGBM] [Info] Start training from score -1.612184
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013691 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2713
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.614165
# [LightGBM] [Info] Start training from score -0.511082
# [LightGBM] [Info] Start training from score -1.603969
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017347 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3216
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.611744
# [LightGBM] [Info] Start training from score -0.506448
# [LightGBM] [Info] Start training from score -1.620355
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012362 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2503
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.045715 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Total Bins 3296
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.610700
# [LightGBM] [Info] Start training from score -0.511960
# [LightGBM] [Info] Start training from score -1.604788
# [LightGBM] [Info] Start training from score -1.608999
# [LightGBM] [Info] Start training from score -0.508106
# [LightGBM] [Info] Start training from score -1.618085
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018799 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2191
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.600865
# [LightGBM] [Info] Start training from score -0.512655
# [LightGBM] [Info] Start training from score -1.612568
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.041029 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3333
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.623854
# [LightGBM] [Info] Start training from score -0.509072
# [LightGBM] [Info] Start training from score -1.600431
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013463 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1835
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.602389
# [LightGBM] [Info] Start training from score -0.510405
# [LightGBM] [Info] Start training from score -1.617808
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011021 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2367
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.598422
# [LightGBM] [Info] Start training from score -0.514048
# [LightGBM] [Info] Start training from score -1.610865
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014909 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3816
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.609932
# [LightGBM] [Info] Start training from score -0.510259
# [LightGBM] [Info] Start training from score -1.610645
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011523 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2898
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.615985
# [LightGBM] [Info] Start training from score -0.506685
# [LightGBM] [Info] Start training from score -1.615378
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012629 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4005
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.595768
# [LightGBM] [Info] Start training from score -0.512179
# [LightGBM] [Info] Start training from score -1.619191
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013122 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2029
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.613284
# [LightGBM] [Info] Start training from score -0.509310
# [LightGBM] [Info] Start training from score -1.610151
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012526 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3379
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.608123
# [LightGBM] [Info] Start training from score -0.509456
# [LightGBM] [Info] Start training from score -1.614882
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017456 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2192
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.605224
# [LightGBM] [Info] Start training from score -0.509985
# [LightGBM] [Info] Start training from score -1.616206
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013782 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2803
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.599996
# [LightGBM] [Info] Start training from score -0.511356
# [LightGBM] [Info] Start training from score -1.617366
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018510 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1990
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.617532
# [LightGBM] [Info] Start training from score -0.504430
# [LightGBM] [Info] Start training from score -1.620688
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.042317 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2681
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.621464
# [LightGBM] [Info] Start training from score -0.509803
# [LightGBM] [Info] Start training from score -1.600594
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013775 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3025
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.597825
# [LightGBM] [Info] Start training from score -0.509656
# [LightGBM] [Info] Start training from score -1.624744
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.041962 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3506
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.611854
# [LightGBM] [Info] Start training from score -0.512033
# [LightGBM] [Info] Start training from score -1.603424
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012671 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3006
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.603260
# [LightGBM] [Info] Start training from score -0.513003
# [LightGBM] [Info] Start training from score -1.609109
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012778 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3088
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.593283
# [LightGBM] [Info] Start training from score -0.512619
# [LightGBM] [Info] Start training from score -1.620410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.041338 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3784
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.608013
# [LightGBM] [Info] Start training from score -0.510862
# [LightGBM] [Info] Start training from score -1.610755
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013830 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3296
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.618804
# [LightGBM] [Info] Start training from score -0.510880
# [LightGBM] [Info] Start training from score -1.599996
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013123 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3052
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.614055
# [LightGBM] [Info] Start training from score -0.507413
# [LightGBM] [Info] Start training from score -1.615102
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.043354 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3221
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.610755
# [LightGBM] [Info] Start training from score -0.508343
# [LightGBM] [Info] Start training from score -1.615599
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016328 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2207
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.610810
# [LightGBM] [Info] Start training from score -0.510150
# [LightGBM] [Info] Start training from score -1.610096
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012540 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3210
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.610975
# [LightGBM] [Info] Start training from score -0.510131
# [LightGBM] [Info] Start training from score -1.609986
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013105 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2606
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.614826
# [LightGBM] [Info] Start training from score -0.504648
# [LightGBM] [Info] Start training from score -1.622742
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013895 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2195
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.614716
# [LightGBM] [Info] Start training from score -0.510935
# [LightGBM] [Info] Start training from score -1.603860
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014278 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2213
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.613449
# [LightGBM] [Info] Start training from score -0.507559
# [LightGBM] [Info] Start training from score -1.615268
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019017 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2558
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.613779
# [LightGBM] [Info] Start training from score -0.507832
# [LightGBM] [Info] Start training from score -1.614110
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012863 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3209
# [LightGBM] [Info] Number of data points in the train set: 91180, number of used features: 20
# [LightGBM] [Info] Start training from score -1.607411
# [LightGBM] [Info] Start training from score -0.509656
# [LightGBM] [Info] Start training from score -1.614992
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012578 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# ...
# [LightGBM] [Info] Total Bins 2211
# [LightGBM] [Info] Number of data points in the train set: 91181, number of used features: 20
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012632 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.[LightGBM] [Info] Start training from score -1.613185
#
# [LightGBM] [Info] Start training from score -0.510636[LightGBM] [Info] Total Bins 3052
#
# [LightGBM] [Info] Number of data points in the train set: 91181, number of used features: 20
# [LightGBM] [Info] Start training from score -1.606273
# [LightGBM] [Info] Start training from score -1.612304
# [LightGBM] [Info] Start training from score -0.509266
# [LightGBM] [Info] Start training from score -1.611260
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012872 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3208
# [LightGBM] [Info] Number of data points in the train set: 91181, number of used features: 20
# [LightGBM] [Info] Start training from score -1.609175
# [LightGBM] [Info] Start training from score -0.510051
# [LightGBM] [Info] Start training from score -1.612030
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013429 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2195
# [LightGBM] [Info] Number of data points in the train set: 91181, number of used features: 20
# [LightGBM] [Info] Start training from score -1.608298
# [LightGBM] [Info] Start training from score -0.510270
# [LightGBM] [Info] Start training from score -1.612249
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012933 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3024
# [LightGBM] [Info] Number of data points in the train set: 91181, number of used features: 20
# [LightGBM] [Info] Start training from score -1.601964
# [LightGBM] [Info] Start training from score -0.509978
# [LightGBM] [Info] Start training from score -1.619535
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012624 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2027
# [LightGBM] [Info] Number of data points in the train set: 91181, number of used features: 20
# [LightGBM] [Info] Start training from score -1.611535
# [LightGBM] [Info] Start training from score -0.511861
# [LightGBM] [Info] Start training from score -1.604253
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011898 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3295
# [LightGBM] [Info] Number of data points in the train set: 91181, number of used features: 20
# [LightGBM] [Info] Start training from score -1.603162
# [LightGBM] [Info] Start training from score -0.510106
# [LightGBM] [Info] Start training from score -1.617930
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018686 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1986
# [LightGBM] [Info] Number of data points in the train set: 91181, number of used features: 20
# [LightGBM] [Info] Start training from score -1.609888
# [LightGBM] [Info] Start training from score -0.506223
# [LightGBM] [Info] Start training from score -1.622919
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013408 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3003
# [LightGBM] [Info] Number of data points in the train set: 91181, number of used features: 20
# [LightGBM] [Info] Start training from score -1.610931
# [LightGBM] [Info] Start training from score -0.512575
# [LightGBM] [Info] Start training from score -1.602727
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017844 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2204
# [LightGBM] [Info] Number of data points in the train set: 91181, number of used features: 20
# [LightGBM] [Info] Start training from score -1.609778
# [LightGBM] [Info] Start training from score -0.509686
# [LightGBM] [Info] Start training from score -1.612524
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012454 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3375
# [LightGBM] [Info] Number of data points in the train set: 91181, number of used features: 20
# [LightGBM] [Info] Start training from score -1.603162
# [LightGBM] [Info] Start training from score -0.511952
# [LightGBM] [Info] Start training from score -1.612359
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014306 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3220
# [LightGBM] [Info] Number of data points in the train set: 91181, number of used features: 20
# [LightGBM] [Info] Start training from score -1.617985
# [LightGBM] [Info] Start training from score -0.506787
# [LightGBM] [Info] Start training from score -1.613075
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013788 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2462
# [LightGBM] [Info] Number of data points in the train set: 91181, number of used features: 20
# [LightGBM] [Info] Start training from score -1.605945
# [LightGBM] [Info] Start training from score -0.513710
# [LightGBM] [Info] Start training from score -1.604307
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.044325 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3207
# [LightGBM] [Info] Number of data points in the train set: 91181, number of used features: 20
# [LightGBM] [Info] Start training from score -1.606984
# [LightGBM] [Info] Start training from score -0.509887
# [LightGBM] [Info] Start training from score -1.614727
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018275 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2189
# [LightGBM] [Info] Number of data points in the train set: 91181, number of used features: 20
# [LightGBM] [Info] Start training from score -1.606219
# [LightGBM] [Info] Start training from score -0.508901
# [LightGBM] [Info] Start training from score -1.618483
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017660 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3500
# [LightGBM] [Info] Number of data points in the train set: 91181, number of used features: 20
# [LightGBM] [Info] Start training from score -1.618151
# [LightGBM] [Info] Start training from score -0.509740
# [LightGBM] [Info] Start training from score -1.604035
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012869 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2603
# [LightGBM] [Info] Number of data points in the train set: 91181, number of used features: 20
# [LightGBM] [Info] Start training from score -1.614176
# [LightGBM] [Info] Start training from score -0.505913
# [LightGBM] [Info] Start training from score -1.619535
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.045588 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3086
# [LightGBM] [Info] Number of data points in the train set: 91181, number of used features: 20
# [LightGBM] [Info] Start training from score -1.607039
# [LightGBM] [Info] Start training from score -0.511641
# [LightGBM] [Info] Start training from score -1.609394
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018016 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2554
# [LightGBM] [Info] Number of data points in the train set: 91181, number of used features: 20
# [LightGBM] [Info] Start training from score -1.608791
# [LightGBM] [Info] Start training from score -0.511111
# [LightGBM] [Info] Start training from score -1.609230
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006049 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2371
# [LightGBM] [Info] Number of data points in the train set: 91181, number of used features: 20
# [LightGBM] [Info] Start training from score -1.602727
# [LightGBM] [Info] Start training from score -0.510690
# [LightGBM] [Info] Start training from score -1.616603
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005871 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2238
# [LightGBM] [Info] Number of data points in the train set: 91181, number of used features: 20
# [LightGBM] [Info] Start training from score -1.599844
# [LightGBM] [Info] Start training from score -0.513509
# [LightGBM] [Info] Start training from score -1.611040
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /export/home/darpan/work_dir/FOML_hkthn/src/bagging.ipynb Cell 10 line 9
#       <a href='vscode-notebook-cell://ssh-remote%2B192.168.167.135/export/home/darpan/work_dir/FOML_hkthn/src/bagging.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> acc = []
#       <a href='vscode-notebook-cell://ssh-remote%2B192.168.167.135/export/home/darpan/work_dir/FOML_hkthn/src/bagging.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> for (train, test), i in zip(cv.split(X_train, y_train), range(n_splits)):
# ----> <a href='vscode-notebook-cell://ssh-remote%2B192.168.167.135/export/home/darpan/work_dir/FOML_hkthn/src/bagging.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>     bagging_clf.fit(X_train.iloc[train], y_train.iloc[train])
#      <a href='vscode-notebook-cell://ssh-remote%2B192.168.167.135/export/home/darpan/work_dir/FOML_hkthn/src/bagging.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>     train_preds = bagging_clf.predict(X_train.iloc[train])
#      <a href='vscode-notebook-cell://ssh-remote%2B192.168.167.135/export/home/darpan/work_dir/FOML_hkthn/src/bagging.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>     valid_preds = bagging_clf.predict(X_train.iloc[test])
#
# File ~/anaconda3/envs/env_1/lib/python3.11/site-packages/sklearn/utils/validation.py:66, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      64 extra_args = len(args) - len(all_args)
#      65 if extra_args <= 0:
# ---> 66     return f(*args, **kwargs)
#      68 # extra_args > 0
#      69 args_msg = [
#      70     "{}={}".format(name, arg)
#      71     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      72 ]
#
# File ~/anaconda3/envs/env_1/lib/python3.11/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/envs/env_1/lib/python3.11/site-packages/sklearn/ensemble/_bagging.py:402, in BaseBagging.fit(self, X, y, sample_weight, **fit_params)
#     399     sample_weight = _check_sample_weight(sample_weight, X, dtype=None)
#     400     fit_params["sample_weight"] = sample_weight
# --> 402 return self._fit(X, y, max_samples=self.max_samples, **fit_params)
#
# File ~/anaconda3/envs/env_1/lib/python3.11/site-packages/sklearn/ensemble/_bagging.py:545, in BaseBagging._fit(self, X, y, max_samples, max_depth, check_input, **fit_params)
#     542 seeds = random_state.randint(MAX_INT, size=n_more_estimators)
#     543 self._seeds = seeds
# --> 545 all_results = Parallel(
#     546     n_jobs=n_jobs, verbose=self.verbose, **self._parallel_args()
#     547 )(
#     548     delayed(_parallel_build_estimators)(
#     549         n_estimators[i],
#     550         self,
#     551         X,
#     552         y,
#     553         seeds[starts[i] : starts[i + 1]],
#     554         total_n_estimators,
#     555         verbose=self.verbose,
#     556         check_input=check_input,
#     557         fit_params=routed_params.estimator.fit,
#     558     )
#     559     for i in range(n_jobs)
#     560 )
#     562 # Reduce
#     563 self.estimators_ += list(
#     564     itertools.chain.from_iterable(t[0] for t in all_results)
#     565 )
#
# File ~/anaconda3/envs/env_1/lib/python3.11/site-packages/sklearn/utils/parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File ~/anaconda3/envs/env_1/lib/python3.11/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File ~/anaconda3/envs/env_1/lib/python3.11/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File ~/anaconda3/envs/env_1/lib/python3.11/site-packages/joblib/parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
# print average f1 and accuracy
print(f"Average F1: {np.mean(f1):.4f}")
print(f"Average Accuracy: {np.mean(acc):.4f}")
# Out:
# Average F1: 0.4454
# Average Accuracy: 0.4479

# %%
# test prediction
test_preds = bagging_clf.predict(test_data)

# map the target back to the original classes
target_mapping_rev = {0: 'low', 1: 'medium', 2: 'high'}
test_preds = pd.Series(test_preds).map(target_mapping_rev)

# Save the predictions to a CSV file
output = pd.DataFrame({'UID': test_data.index, 'Target': test_preds})
output.to_csv('../data/output/bagging_LGBM.csv', index=False)

# %%
# unique output
print(output['Target'].value_counts())
# Out:
# Target
# medium    7246
# low       4598
# high      4077
# Name: count, dtype: int64
